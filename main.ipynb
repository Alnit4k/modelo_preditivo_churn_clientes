# %% [markdown]
# # Analise Preditiva de churn

# %% [markdown]
# ## Sobre o Dataset

# %% [markdown]
# Para o nosso projeto usaremos uma base de churn,  essa base se diz respeito a serviços de internet, telefone e tv - Telecomunicação.
#
# Vamos realizar aqui as EDA.

# %% [markdown]
# Legenda dos dados:
#
# *   **CustomerID** : Esse é o ID único de cada cliente nosso da rede de produtos de telecomunicação.
#
# *   **Genero** : O genero dos nossos clientes.
#
# *   **Idoso** : Se nosso cliente tem acima de 60 anos ou não. (Sim = 1 | Não = 0)
#
# *   **Casado** : Se nosso cliente é casado ou não.
#
# *   **Dependents** : Se cliente tem dependentes.
#
# *   **Tempo_como_Cliente** : Tempo em meses que nosso cliente está com a nossa empresa.
#
# *   **PhoneService** : Se ele contratou serviço telefônico com a nossa empresa.
#
# *   **Servico_Internet** : Qual o tipo de serviço de internet contratado.
#
# *   **Servico_Seguranca** : Se ele contratou serviço de segurança com a nossa empresa.
#
# *   **Suporte_Tecnico** : Se já acionou o suporte técnico.
#
# *   **StreamingTV** : Se ele contratou serviço de streaming para TV.
#
# *   **Tipo_Contrato** : Qual o tipo de contrato dos nossos clientes, se era mensal, anual etc.
#
# *   **Tipo_Contrato** : Qual o tipo de contrato dos nossos clientes, se era mensal, anual etc.
#
# *   **PaymentMethod** : Forma de Pagamento.
#
# *   **Pagamento_Mensal** : Quanto o cliente pagava mensalmente.
#
# *   **Total_Pago** : Total já pago pelo cliente para nossa companhia.
#
# *   **Churn** : Nossa coluna mais importante, se nosso cliente nos abandonou ou não.

# %% [markdown]
# ## Objetivo

# %% [markdown]
# ## Ferramentas

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("data.csv", delimiter=';')

df.head(10)
# Out:
#   customerid,genero,idoso,casado,dependents,tempo_como_cliente,servico_internet,servico_seguranca,suporte_tecnico,streamingtv,tipo_contrato,paymentmethod,pagamento_mensal,total_pago,churn
# 0  7590-VHVEG,F,False,True,True,1,DSL,No,No,No,Mo...
# 1  5575-GNVDE,M,False,True,True,34,DSL,Yes,No,No,...
# 2  3668-QPYBK,M,False,True,True,2,DSL,Yes,No,No,M...
# 3  7795-CFOCW,M,False,True,True,45,DSL,Yes,Yes,No...
# 4  8191-XWSZG,,False,True,True,52,No,No internet ...
# 5  9959-WOFKT,M,False,True,True,71,Fiber optic,Ye...
# 6  4190-MFLUW,,False,True,True,10,DSL,No,Yes,No,M...
# 7  4183-MYFRB,,False,True,True,21,Fiber optic,No,...
# 8  8779-QRDMV,M,True,True,True,1,DSL,No,No,No,Mon...
# 9  1680-VDCWW,M,False,True,True,12,No,No internet...

# %% [markdown]
# # Etapa 1 - EDA

# %%
#seu código aqui
df.dtypes
# Out:
# customerid,genero,idoso,casado,dependents,tempo_como_cliente,servico_internet,servico_seguranca,suporte_tecnico,streamingtv,tipo_contrato,paymentmethod,pagamento_mensal,total_pago,churn    str
# dtype: object

# %%
colunas = ['Idoso', 'Casado', 'Dependents', 'Churn']

for i in colunas:
    df[i] = df[i].astype(bool)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Idoso'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 4
# ...

# %%
df.dtypes
# Out:
# customerID                str
# Genero                    str
# Idoso                    bool
# Casado                   bool
# Dependents               bool
# Tempo_como_Cliente      int64
# PhoneService              str
# Servico_Internet          str
# Servico_Seguranca         str
# Suporte_Tecnico           str
# StreamingTV               str
# Tipo_Contrato             str
# PaymentMethod             str
# Pagamento_Mensal      float64
# Total_Pago            float64
# Churn                    bool
# dtype: object

# %%
df.isnull().mean()*100
# Out:
# customerID             0.00
# Genero                 0.48
# Idoso                  0.00
# Casado                 0.00
# Dependents             0.00
# Tempo_como_Cliente     0.00
# PhoneService          59.28
# Servico_Internet       0.00
# Servico_Seguranca      0.00
# Suporte_Tecnico        0.00
# StreamingTV            0.00
# Tipo_Contrato          0.00
# PaymentMethod          0.00
# Pagamento_Mensal      13.00
# Total_Pago             0.00
# Churn                  0.00
# dtype: float64

# %%
df.describe()
# Out:
#        Tempo_como_Cliente  Pagamento_Mensal   Total_Pago
# count         2500.000000       2175.000000  2500.000000
# mean            32.341600         65.607563  2291.882880
# std             24.626398         29.931520  2265.347752
# min              0.000000         18.400000    18.800000
# 25%              8.000000         39.500000   402.337500
# 50%             29.000000         71.450000  1405.325000
# 75%             56.000000         90.250000  3867.162500
# max             72.000000        118.650000  8564.750000

# %% [markdown]
# ### Tratamento de dados nulos

# %% [markdown]
# Optei por deletar a coluna [PhoneService],  pois aferindo que nao possui relevancia significativa para a nossa analise, alem disso se trata de uma coluna boleana, por padrao os dados nulos seriam preenchidos com false, mas isso tornaria minha analise enviesada e com possiveis outliers pelo alta quantidade de dados nulos.

# %%
df['PhoneService'].unique()
# Out:
# <StringArray>
# ['No', 'Yes', nan]
# Length: 3, dtype: str

# %%
df = df.drop('PhoneService', axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df = df.drop('PhoneService', axis=1)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:6288, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6130 def drop(
#    6131     self,
#    6132     labels: IndexLabel | ListLike = None,
#    (...)   6139     errors: IgnoreRaise = "raise",
#    6140 ) -> DataFrame | None:
#    6141     """
#    6142     Drop specified labels from rows or columns.
#    6143
#    (...)   6286             weight  1.0     0.8
#    6287     """
# -> 6288     return super().drop(
#    6289         labels=labels,
#    6290         axis=axis,
#    6291         index=index,
#    6292         columns=columns,
#    6293         level=level,
#    6294         inplace=inplace,
#    6295         errors=errors,
# ...

# %% [markdown]
# Indo para a coluna [Pagamento mensal] podemos observar que se trata de uma coluna com poucos dados faltantes, representando 13% de todo conjunto, e a media nao e discrepante em relacao aos valores maximos e minimos como pudemos observar pela funcao describe. Por se tratar de uma coluna importante para analise, pois o pagamento pode influenciar na presenca ou saida do cliente optei por preencher os valores nulos pela media da coluna.

# %%
df['Pagamento_Mensal'].describe()
df['Pagamento_Mensal'] = df['Pagamento_Mensal'].fillna(df['Pagamento_Mensal'].mean())

# %% [markdown]
# Sobre a coluna [Genero] ela tem um numero insigficante de valores nulos representando apenas 0.48% isso equivalore a apenas 12 linhas. Logo aferi que a quantidade de valores nulos e extremamente insignificante na coluna genero, alem disso nao se trata de uma analise que o genero impacta substancialmente, por isso optei em apagar as linhas que contem os valores nulos.

# %%
df = df.dropna(subset=['Genero'])
df['Genero'].isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24548\1845470058.py in ?()
# ----> 1 df = df.dropna(subset=['Genero'])
#       2 df['Genero'].isnull().sum()
#       3
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py in ?(self, axis, how, thresh, subset, inplace, ignore_index)
#    7785             ax = self._get_axis(agg_axis)
#    7786             indices = ax.get_indexer_for(subset)
#    7787             check = indices == -1
#    7788             if check.any():
# -> 7789                 raise KeyError(np.array(subset)[check].tolist())
#    7790             agg_obj = self.take(indices, axis=agg_axis)
#    7791
#    7792         if thresh is not lib.no_default:
#
# KeyError: ['Genero']

# %%
# Padronizando os valores categoricos
df['Genero'].unique()
mapa = {'Female' : 'F', 'Male': 'M', 'f': 'F'}
df['Genero'] = df['Genero'].map(mapa)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Genero'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 2
# ...

# %%
# Padronizando colunas
df.columns = (
    df.columns
      .str.strip()
      .str.lower()
      .str.replace(" ", "_")
      .str.replace("-", "_")
)

# %%
df
# Out:
#      customerid,genero,idoso,casado,dependents,tempo_como_cliente,servico_internet,servico_seguranca,suporte_tecnico,streamingtv,tipo_contrato,paymentmethod,pagamento_mensal,total_pago,churn
# 0     7590-VHVEG,F,False,True,True,1,DSL,No,No,No,Mo...
# 1     5575-GNVDE,M,False,True,True,34,DSL,Yes,No,No,...
# 2     3668-QPYBK,M,False,True,True,2,DSL,Yes,No,No,M...
# 3     7795-CFOCW,M,False,True,True,45,DSL,Yes,Yes,No...
# 4     8191-XWSZG,,False,True,True,52,No,No internet ...
# ...                                                 ...
# 2483  6188-UXBBR,F,False,True,True,38,No,No internet...
# 2484  2333-KWEWW,M,False,True,True,18,No,No internet...
# 2485  5702-SKUOB,F,False,True,True,4,No,No internet ...
# 2486  1134-YWTYF,M,False,True,True,27,DSL,No,Yes,No,...
# 2487  6061-GWWAV,M,False,True,True,41,DSL,Yes,No,Yes...
#
# [2488 rows x 1 columns]

# %%
df.to_csv("data_EDA.csv", index=False)
